# %%
import pandas as pd
import networkx as nx
from itertools import combinations
from collections import Counter

songs = pd.read_csv('datadump/songs_no_dublicates.csv',
                    usecols=['recording_mbid','first_release_year'])
writes = pd.read_csv('datadump/writerships.csv',
                     usecols=['recording_mbid','writer_id'])

songs = (
    songs
    .sort_values('first_release_year')
    .drop_duplicates('recording_mbid', keep='first')
)

songs['decade'] = (songs.first_release_year // 10) * 10

wr = writes.merge(songs[['recording_mbid','decade']],
                  on='recording_mbid', how='left')

wcnt = (
    wr
    .groupby(['writer_id','decade'])
    .size()
    .reset_index(name='count')
)

idx = wcnt.groupby('writer_id')['count'].idxmax()

writer_decade_map = (
    wcnt
    .loc[idx, ['writer_id','decade']]
    .set_index('writer_id')['decade']
    .to_dict()
)

def build_ww_graph_assigned_decade(decade_start):
    decade_end = decade_start + 9
    
    dec_recs = songs[
        songs.first_release_year.between(decade_start, decade_end)
    ].recording_mbid

    valid_writers = {w for w,d in writer_decade_map.items() if d == decade_start}

    wr_sub = writes[
        writes.recording_mbid.isin(dec_recs) &
        writes.writer_id.isin(valid_writers)
    ]

    pair_counter = Counter()
    for _, grp in wr_sub.groupby('recording_mbid'):
        ws = sorted(grp['writer_id'].unique())
        if len(ws) < 2:
            continue
        for w1, w2 in combinations(ws, 2):
            pair_counter[(w1, w2)] += 1
    G = nx.Graph()
    for (w1, w2), weight in pair_counter.items():
        G.add_edge(w1, w2, weight=weight)

    return G

writer_graphs = {}
for start in range(1960, 2030, 10):
    label = f"{start}s"
    G = build_ww_graph_assigned_decade(start)
    writer_graphs[label] = G
    print(f"{label}: {G.number_of_nodes():>4} noder  | {G.number_of_edges():>6} kanter")
# Out:
# 1960s:  279 noder  |    188 kanter
# 1970s:  425 noder  |    347 kanter
# 1980s:  497 noder  |    453 kanter
# 1990s: 2455 noder  |   3512 kanter
# 2000s: 4236 noder  |   9590 kanter
# 2010s: 5072 noder  |  17092 kanter
# 2020s: 2479 noder  |   8259 kanter

# %%
import networkx as nx
import numpy as np
import pandas as pd
from collections import Counter

def gini(array):
    """Gini coefficient for inequality of degree distribution."""
    if len(array) == 0:
        return np.nan
    array = np.sort(np.array(array, dtype=float))
    n = len(array)
    cum = np.cumsum(array)
    return (n + 1 - 2 * cum.sum() / cum[-1]) / n

def safe_metric(func, *args, **kwargs):
    """Return NaN instead of blowing up on disconnected graphs."""
    try:
        return func(*args, **kwargs)
    except (nx.NetworkXError, ZeroDivisionError):
        return np.nan
    
def decade_metrics(G, top_n=5):
    """
    Compute a dictionary of graph statistics that are easy to interpret
    in a social-science write-up.
    """
    n = G.number_of_nodes()
    m = G.number_of_edges()
    deg   = dict(G.degree())
    deg_w = dict(G.degree(weight="weight"))
    degrees = np.array(list(deg.values()))

    if n > 0:
        GCC = max(nx.connected_components(G), key=len)
        sub = G.subgraph(GCC)
    else:
        sub = G

    return {
        "nodes"             : n,
        "edges"             : m,
        "avg_degree"        : degrees.mean()          if n else np.nan,
        "median_degree"     : np.median(degrees)      if n else np.nan,
        "degree_gini"       : gini(degrees),          # inequality measure
        "density"           : nx.density(G),
        "avg_clustering"    : safe_metric(nx.average_clustering, G, weight=None),
        "assortativity_deg" : safe_metric(nx.degree_assortativity_coefficient, G),
        "avg_path_length"   : safe_metric(nx.average_shortest_path_length, sub),
        "diameter"          : safe_metric(nx.diameter, sub),
        **{
            "n_communities": len(comms := list(nx.algorithms.community.greedy_modularity_communities(G))),
            "modularity"   : nx.algorithms.community.modularity(G, comms)
        },
        "top_writers"       : ", ".join(
            f"{wid}:{int(deg_w[wid])}"
            for wid, _ in Counter(deg_w).most_common(top_n)
        )
    }

records = []
for decade, G in writer_graphs.items():
    rec = decade_metrics(G)
    rec["decade"] = decade
    records.append(rec)

metrics_df = (pd.DataFrame(records)
                .sort_values("decade")
                .set_index("decade")
                .round(3))

display(metrics_df)          
metrics_df.to_csv("decade_network_metrics_2.csv")
# Out:
#         nodes  edges  avg_degree  median_degree  degree_gini  density  \
# decade
# 1960s     279    188       1.348            1.0        0.204    0.005
# 1970s     425    347       1.633            1.0        0.308    0.004
# 1980s     497    453       1.823            1.0        0.306    0.004
# 1990s    2455   3512       2.861            2.0        0.465    0.001
# 2000s    4236   9590       4.528            2.0        0.550    0.001
# 2010s    5072  17092       6.740            3.0        0.583    0.001
# 2020s    2479   8259       6.663            4.0        0.519    0.003
#
#         avg_clustering  assortativity_deg  avg_path_length  diameter  \
# decade
# 1960s            0.231              0.792            1.333         2
# 1970s            0.272              0.844            2.475         5
# 1980s            0.406              0.811            1.500         2
# 1990s            0.421              0.283            7.668        21
# 2000s            0.511              0.022            5.564        16
# 2010s            0.615             -0.016            4.200        13
# 2020s            0.710             -0.003            4.171        11
#
#         n_communities  modularity  \
# decade
# 1960s             122       0.979
# 1970s             169       0.950
# 1980s             186       0.952
# 1990s             581       0.879
# 2000s             597       0.812
# 2010s             609       0.638
# 2020s             203       0.656
#
#                                               top_writers
# decade
# 1960s   50986f3f-f7f3-42bb-b14f-17e8c6bab222:19, 9b142...
# 1970s   227c88c7-ea23-49fd-8cc7-f737754ad26d:47, 4f079...
# 1980s   266cd37e-4198-4b33-a20b-37994a25b2d8:84, 2b09f...
# 1990s   7f347782-eb14-40c3-98e2-17b6e1bfe56c:3876, a94...
# 2000s   4d5447d7-c61c-4120-ba1b-d7f471d385b9:3826, ba5...
# 2010s   6622a50e-5206-44d0-9ad5-96047a726dcf:2622, 186...
# 2020s   9032140b-c6ba-448d-8f05-5ac16e3aa165:1015, 115...

# %%
import pandas as pd

# 1) Indlæs dine data
df = pd.read_csv('decade_network_metrics.csv')
artist_lookup = pd.read_csv('datadump/artists_all.csv', usecols=['artist_mbid', 'name'])

# 2) Lav et opslag fra MBID til navn
id_to_name = artist_lookup.set_index('artist_mbid')['name'].to_dict()

# 3) Funktion til at erstatte MBID i top_writers med navn
def map_top_writers(cell: str) -> str:
    items = [item.strip() for item in cell.split(',')]
    mapped = []
    for item in items:
        if ':' in item:
            mbid, count = item.split(':', 1)
            name = id_to_name.get(mbid, mbid)
            mapped.append(f"{name}:{count}")
        else:
            mapped.append(item)
    return ', '.join(mapped)

# 4) Anvend funktionen
df['top_writers_names'] = df['top_writers'].apply(map_top_writers)

# 5) Fjern enhver begrænsning på kolonne-bredde
pd.set_option('display.max_colwidth', None)

# 6) Print alle rækker og kolonner uden afkortning
print(df[['decade','top_writers_names']].to_string(index=False))

# %%
# —— Louvain‐analyse for hver dekadegraf ——

import pandas as pd
import networkx as nx
import community as louvain  # pip install python-louvain

# Antag at du allerede har kørt koden fra før og har:
# artist_graphs: dict med grafer per dekade, f.eks. {'1960s': G_1960s, …}

# Indlæs navne‐opslag (hvis du vil printe navne senere)
artist_lookup = pd.read_csv('datadump/artists_all.csv',
                           usecols=['artist_mbid','name'])
id_to_name = artist_lookup.set_index('artist_mbid')['name'].to_dict()

for decade, G in writer_graphs.items():
    if G.number_of_nodes() == 0:
        print(f"{decade}: ingen noder, springer over\n")
        continue

    # 1) Beregn Louvain‐partition
    partition = louvain.best_partition(G, weight='weight')

    # 2) Beregn modularity
    mod = louvain.modularity(partition, G, weight='weight')

    # 3) Saml fællesskaber og størrelser
    from collections import Counter
    comm_sizes = Counter(partition.values())
    top_comms = comm_sizes.most_common(3)

    # 4) Print resultater
    print(f"{decade}:")
    print(f"  • Noder: {G.number_of_nodes()}, Kanter: {G.number_of_edges()}")
    print(f"  • Community‐count: {len(comm_sizes)}, Modularity: {mod:.3f}")
    for comm_id, size in top_comms:
        # valgfrit: vis 3 navneprøver fra community
        members = [n for n,c in partition.items() if c==comm_id]
        sample = [id_to_name.get(m, m) for m in members[:100]]
        print(f"    – Fællesskab {comm_id}: {size} noder ({', '.join(sample)})")
    print()
# Out:
# 1960s:
#   • Noder: 279, Kanter: 188
#   • Community‐count: 122, Modularity: 0.979
#     – Fællesskab 24: 6 noder (Noel Paul Stookey, Peter Yarrow, Mary Travers, Robert Bannard, Elaina Mezzetti, Milt Okun)
#     – Fællesskab 19: 4 noder (Ernst Van Rooyen, Anton de Waal, Peter Ström, Willy Berking)
#     – Fællesskab 33: 4 noder (Prince Leleiohoku, Johnny Noble, Tommy Harrison, Bill Cogswell)
#
# 1970s:
#   • Noder: 425, Kanter: 347
#   • Community‐count: 169, Modularity: 0.950
#     – Fællesskab 19: 16 noder (Larry Butler, Roger Bowling, Larry Cheshier, Murry Kellum, Glenn Sutton, Arthur Leo “Doodle” Owens, Darrell Edwards, George Richey, Frank Dycus, Jan Crutchfield, Mac Curtis, Ben Peters, Paul Tannen, Larry Kingston, Gene Vowell, Sonny Ledet)
#     – Fællesskab 63: 9 noder (Walter Lester, Lennie Martin, William King III, Janet Vogel, Joseph Verscharen, Jimmy Beaumont, John Taylor, Joe Rock, Larry Martin)
#     – Fællesskab 135: 7 noder (Mark Hallman, Michael Wooten, Robert McEntee, Richard Hardy, Miguel Rivera, Rob Galloway, Rick Evers)
#
# 1980s:
#   • Noder: 497, Kanter: 453
#   • Community‐count: 186, Modularity: 0.952
#     – Fællesskab 38: 137 noder (Price, Ink, Raphael Saadiq, Dave Hamelin, Chris Penny, Honey Redmond, Denisia “Blu June” Andrews, Kim Cooper, Peter Rauhofer, 070 Shake, Leven Kali, Lucky Daye, John Holiday, Brittany Chi Coney, Levar Coppin, Saliou Diagne, Luke Solomon, Nija, Simon Mårtensson, Cam, Derek Dixie, Snoh Aalegra, Nicholas Breton, Rostam, Clairo, bülow, Gabriel Noel, Michael Price, Dan Walsh, Dixson, Ricky Lawson, Cadenza, Sean Seaton, Julian Mason, Cherdericka Nichols, Jabbar Stevens, BEAM, Arlo Parks, GianLuca Buccellati, Michael Tucker, Rageous, Eric Snead, Michael Cox, Andrew Richardson, Moi Renee, Count Maurice, Kevin Marquis Bellmon, Adam Pigott, Big Freedia, Allen George, Fred McFarlane, Darhyl Camper, Jr., Kaydence, Caso, Akil King, Donna Summer, Jameil Aossey, A. G. Cook, Romil Hemnani, Baird, D.A. Got That Dope, Ezemdi Chikwendu, Dominik Redenczki, Jack Rochon, John Byron, Merlyn Wood, Dom McLennon, Kevin Abstract, bearface., Brian Casey, Ryan Beatty, Matt Champion, JOBA, Jabari Manwa, Chuks Chiejine, Miranda J, Marcus Reddick, Ramesh Srivastava, Killah B, Nate Ferraro, Lowell, Buddy Ross, Alejandro Villasana, Harry Edwards, Giift, Deradoorian, Allen McGrier, Almando Cresso, Tizita Makuria, Teena Marie, Curtis Alan Jones, Dave Giles II, Corece Smith, Ez Mil, Callum Merrett, Ewan Merrett, Dustin Bowie, Daniel Memmi, Jesse “Corporal” Wilson, Jozzy)

# %%
import json
from pathlib import Path
from collections import Counter, defaultdict
from itertools import combinations

import pandas as pd
import networkx as nx
import community as community_louvain

# ─── CONFIG ──────────────────────────────────────────────────────────────────────
OUTPUT_DIR = Path('public/data')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
DECADES = list(range(1960, 2030, 10))

# ─── 0) LOAD & CLEAN ─────────────────────────────────────────────────────────────
songs = pd.read_csv(
    'datadump/songs_no_dublicates.csv',
    usecols=['recording_mbid','first_release_year']
).dropna(subset=['first_release_year'])
songs = (
    songs
    .sort_values('first_release_year')
    .drop_duplicates('recording_mbid', keep='first')
)
songs['decade'] = (songs.first_release_year // 10) * 10

writes = pd.read_csv(
    'datadump/writerships.csv',
    usecols=['recording_mbid','writer_id']
)

# ─── 0b) WRITER NAME LOOKUP ──────────────────────────────────────────────────────
# Re-use your artist lookup for writer names
artists_all = pd.read_csv(
    'datadump/artists_all.csv',
    usecols=['artist_mbid','name'],
    dtype=str
)
writer2name = artists_all.set_index('artist_mbid')['name'].to_dict()

# ─── 1) ASSIGN EACH WRITER TO THEIR “PEAK” DECADE ───────────────────────────────
wr = writes.merge(
    songs[['recording_mbid','decade']],
    on='recording_mbid', how='left'
)
wcnt = (
    wr
    .groupby(['writer_id','decade'])
    .size()
    .reset_index(name='count')
)
idx = wcnt.groupby('writer_id')['count'].idxmax()
writer_decade_map = (
    wcnt
    .loc[idx, ['writer_id','decade']]
    .set_index('writer_id')['decade']
    .to_dict()
)

# ─── 2) BUILD writer–writer GRAPH FOR A GIVEN DECADE ────────────────────────────
def build_ww_graph_assigned_decade(decade_start):
    decade_end = decade_start + 9

    recs = set(
        songs.loc[
            songs.first_release_year.between(decade_start, decade_end),
            'recording_mbid'
        ]
    )
    valid_writers = { w for w,d in writer_decade_map.items() if d == decade_start }

    sub = writes[
        writes.recording_mbid.isin(recs) &
        writes.writer_id.isin(valid_writers)
    ]

    cnt = Counter()
    for _, grp in sub.groupby('recording_mbid'):
        ws = sorted(grp['writer_id'].unique())
        if len(ws) < 2:
            continue
        for w1, w2 in combinations(ws, 2):
            cnt[(w1, w2)] += 1

    G = nx.Graph()
    for (w1, w2), weight in cnt.items():
        G.add_edge(w1, w2, weight=weight)
    return G

# ─── 3) ITERATE DECADES ──────────────────────────────────────────────────────────
for dec in DECADES:
    label = f"{dec}s"
    G = build_ww_graph_assigned_decade(dec)

    n_nodes = G.number_of_nodes()
    n_edges = G.number_of_edges()
    density = nx.density(G)

    partition = {}
    if n_edges > 0:
        partition = community_louvain.best_partition(G, weight='weight')

    # build community→member list (with names)
    comm2nodes = defaultdict(list)
    for wid, cid in partition.items():
        comm2nodes[cid].append(wid)

    # print summary
    print(f"\n=== Writer–Writer {label} ===")
    print(f"Nodes: {n_nodes}, Edges: {n_edges}, Density: {density:.4f}")
    print(f"Communities: {len(comm2nodes)}")
    for cid, members in comm2nodes.items():
        # show first 10 names
        names = [ writer2name.get(w, w) for w in members ]
        sample = names if len(names) <= 10 else names[:10] + ['…']
        print(f" • Community {cid} ({len(names)} writers): {sample}")

    # prepare JSON
    nodes = []
    for wid in G.nodes():
        nodes.append({
            "id":        wid,
            "name":      writer2name.get(wid, wid),
            "value":     G.degree(wid, weight='weight'),
            "community": partition.get(wid, 0),
            "genre":     []   # placeholder
        })

    links = [
        { "source": u, "target": v, "value": d["weight"] }
        for u, v, d in G.edges(data=True)
    ]

    out = {"nodes": nodes, "links": links}
    fn = OUTPUT_DIR / f"writer-network-assigned-{label}.json"
    with open(fn, 'w') as fp:
        json.dump(out, fp, indent=2)

    print(f"Wrote JSON → {fn} ({len(nodes)} nodes, {len(links)} links)")
# Out:
# === Writer–Writer 1960s ===
# Nodes: 279, Edges: 188, Density: 0.0048
# Communities: 122
#  • Community 0 (2 writers): ['Tom Jones', 'Harvey Schmidt']
#  • Community 1 (3 writers): ['Harry Rosenthal', 'Jimmy Flynn', 'Alex Sullivan']
#  • Community 2 (2 writers): ['Michael Leonard', 'Herbert Martin']
#  • Community 3 (2 writers): ['Charlie Williams', 'Bobby Bare']
#  • Community 4 (2 writers): ['Shelly Coburn', 'Norman Bergen']
#  • Community 5 (2 writers): ['Alan Freed', 'Bobby Lester']
#  • Community 6 (3 writers): ['Joss Baselli', 'Armand Canfora', 'Michel Jourdan']
#  • Community 84 (2 writers): ['Gail Allen', 'Jeri Southern']
#  • Community 85 (3 writers): ['Joe Lewis', 'Chuck Seitz', 'Jim Denny']
#  • Community 86 (2 writers): ['Billy Towne', 'Μάνος Χατζιδάκις']
#  • Community 87 (2 writers): ['Roberto Livraghi', 'Daniele Pace']
#  • Community 88 (2 writers): ['Erwin King', 'Harry Carlson']
#  • Community 89 (2 writers): ['Pablo Beltrán Ruiz', 'Luis Demetrio']
#  • Community 90 (2 writers): ['Lydia Wood', 'Neil Roth']
#  • Community 91 (2 writers): ['Percy Faith', 'Spence Maxwell']
#  • Community 92 (2 writers): ['Sarah Graham', 'Richard Ahlert']
#  • Community 93 (2 writers): ['Douglas Arthur', 'Herb Hendler']
#  • Community 94 (2 writers): ['Eddie Rambeau', 'Bud Rehak']
#  • Community 95 (2 writers): ['Karl Götz', 'Kurt Hertha']
#  • Community 96 (2 writers): ['Frank Mandel', 'Laurence Schwab']
#  • Community 97 (2 writers): ['James Lipton', 'Laurence Rosenthal']
#  • Community 98 (3 writers): ['Hans-Arno Simon', 'Roger Courcel', 'Fernand Bonifay']
#  • Community 99 (2 writers): ['Alan Blaikley', 'Ken Howard']
#  • Community 100 (2 writers): ['Marge Barton', 'Fred MacRae']
#  • Community 101 (2 writers): ['Richard Howard', 'Bob Ellsworth']
#  • Community 102 (2 writers): ['Adrian Mitchell', 'Richard Peaslee']
#  • Community 103 (3 writers): ['Elise Bretton', 'Mark Lockett', 'Donald Meyer']
#  • Community 104 (2 writers): ['Letta Mbulu', 'Gibson Kente']
#  • Community 105 (2 writers): ['Bud Logan', 'Charles Snoddy']
#  • Community 106 (2 writers): ['Alan Zeffertt', 'Tony Day']
#  • Community 107 (2 writers): ['Michael Canosa', 'Danny Stradella']
#  • Community 108 (2 writers): ['Neil Wolfe', 'Francine Forest']
#  • Community 109 (2 writers): ['Claude Pitkowsky', 'Alain Gaunay']
#  • Community 110 (2 writers): ['Buddy Mize', 'Ira Allen']
#  • Community 111 (2 writers): ['Bertha Scott', 'Jimmy Henderson']
#  • Community 112 (2 writers): ['Hosea Woods', 'Gus Cannon']
#  • Community 113 (2 writers): ['Larry Grounds', 'Faye Keys']
#  • Community 114 (2 writers): ['Alfred Hart Miles', 'Charles A. Zimmerman']
#  • Community 115 (2 writers): ['Ross Burk', 'Mildred Burk']
#  • Community 116 (2 writers): ['Gennaro Ottaviano', 'Salvatore Gambardella']
#  • Community 117 (2 writers): ['Otis Williams', 'Henry Stone']
#  • Community 118 (2 writers): ['Cornelius Grant', 'Eddie Kendricks']
#  • Community 119 (2 writers): ['Léona Gabriel', 'Michel Marc Lanjean']
#  • Community 120 (2 writers): ['Jean Nohain', 'Mireille']
#  • Community 121 (2 writers): ['Jeanette', 'Rafael Turia']
#  • Community 19 (3 writers): ['Renzo Tarabusi', 'Lelio Luttazzi', 'Giulio Scarnicci']
# Wrote JSON → public/data/writer-network-assigned-1960s.json (279 nodes, 188 links)
#
# === Writer–Writer 1970s ===
# Nodes: 425, Edges: 347, Density: 0.0039
# Communities: 169
#  • Community 0 (2 writers): ['Greatrex Newman', 'Vivian Ellis']
#  • Community 1 (2 writers): ['Juan Marcelo', 'Juan Eduardo']
#  • Community 2 (2 writers): ['Carl Malcolm', 'Clive Chin']
#  • Community 3 (2 writers): ['Bill Rice', 'Jerry Foster']
#  • Community 4 (3 writers): ['Danny Hice', 'Ruby Hice', 'Chip Hardy']
#  • Community 5 (5 writers): ['Sylvester Levay', 'Jerry Rix', 'Bruce Hawes', 'Mikki Farrow', 'Melba Moore']
#  • Community 6 (3 writers): ['Toni Tennille', 'Daryl Dragon', 'Dennis Wilson']
#  • Community 7 (3 writers): ['Don Hill', 'Fred Burch', 'Will Young']
#  • Community 8 (2 writers): ['Joe Falsia', 'Stephen Sinclair']
#  • Community 9 (3 writers): ['Dene Anton', 'Bradley Burg', 'Lisa Hartman']
#  • Community 10 (2 writers): ['Vittorino Pecchia', 'Adriano Della Giustina']
#  • Community 11 (2 writers): ['Mira Smith', 'Margaret Lewis']
#  • Community 12 (2 writers): ['Linda Hargrove', 'Michael Nesmith']
#  • Community 13 (2 writers): ['Celia Bass', 'Becki Bluefield']
#  • Community 14 (2 writers): ['Papa John Creach', 'Roger Spotts']
#  • Community 15 (3 writers): ['Marshall Chapman', 'Jim Rushing', 'Cort B. Casady']
#  • Community 18 (16 writers): ['Larry Butler', 'Roger Bowling', 'Larry Cheshier', 'Murry Kellum', 'Glenn Sutton', 'Arthur Leo “Doodle” Owens', 'Darrell Edwards', 'George Richey', 'Frank Dycus', 'Jan Crutchfield', '…']
#  • Community 19 (2 writers): ['Red Sovine', 'Dale Noe']
#  • Community 20 (5 writers): ['Lynn Anderson', 'Johnny Johnson', 'Finn Sidselrud', 'Liz Anderson', 'Dick Land']
#  • Community 21 (2 writers): ['Charles Starr', 'Charles Sciple']
#  • Community 22 (3 writers): ['Alex Zanetis', 'Grady Martin', 'George McCormick']
#  • Community 23 (2 writers): ['Raymond Jeannot', 'Gérard Layani']
#  • Community 24 (2 writers): ['Leona Butrum', 'Nellie Smith']
#  • Community 25 (2 writers): ['Dennis Johnson', 'R. Gary Smith']
#  • Community 26 (3 writers): ['David Wolfert', 'Sue Sheridan', 'Stephen Nelson']
#  • Community 27 (2 writers): ['Alan Gordon', 'Garry Bonner']
#  • Community 28 (2 writers): ['Maurice Tézé', 'Tony Cole']
#  • Community 29 (2 writers): ['Ronnie Scott', 'Steve Wolfe']
#  • Community 30 (3 writers): ['Pat Benatar', 'Harry Chapin', 'Sandra Campbell Chapin']
#  • Community 32 (6 writers): ['Steve Potts', 'Trevor Watts', 'Steve Lacy', '小杉武久', '高橋悠治', 'Maarten Altena']
#  • Community 34 (2 writers): ['Kerry Chater', 'Douglas Foxworthy']
#  • Community 35 (2 writers): ['George Beverly Shea', 'Rhea F. Miller']
#  • Community 36 (2 writers): ['Ayn Robbins', 'Carol Connors']
#  • Community 37 (2 writers): ['Greg Wright', 'Karin Patterson']
#  • Community 38 (5 writers): ['Roy Culbertson', 'Harold Forness', 'Steve Pippin', 'Larry Keith', 'Jim Hurt']
#  • Community 39 (2 writers): ['Gary Cobb', 'Mark Sherrill']
#  • Community 40 (5 writers): ['Bruce Welch', 'Hank Marvin', 'John Rostill', 'Brian Bennett', 'Cliff Richard']
#  • Community 41 (4 writers): ['Kenny Ascher', 'Paul Williams', 'Rupert Holmes', 'Kathy Cooper']
#  • Community 42 (2 writers): ['Carole Smith', 'Sonny James']
#  • Community 43 (2 writers): ['Don Reno', 'Mack Magaha']
#  • Community 44 (2 writers): ['Ted Grouya', 'Edmund Anderson']
#  • Community 45 (3 writers): ['Douglas Brown', 'Thomas Wallington', 'William Bloom']
#  • Community 46 (2 writers): ['“Spider” John Koerner', 'Willie Murphy']
#  • Community 47 (3 writers): ['John Domurad', 'Ed Penney', 'Ron Oates']
#  • Community 48 (2 writers): ['Margie Singleton', 'Leon Ashley']
#  • Community 49 (2 writers): ['Kenny Stover', 'Pam Davis']
#  • Community 50 (2 writers): ['Tom Pick', 'Porter Wagoner']
#  • Community 51 (3 writers): ['Morgan Ames', 'Hank Cicalo', 'Gary King']
#  • Community 52 (2 writers): ['Ronnie Sessions', 'Ray Willis']
#  • Community 53 (2 writers): ['Bobby Montgomery', 'Earl Sinks']
#  • Community 54 (2 writers): ['Michael Allison', 'Peter Sills']
#  • Community 55 (3 writers): ['Lester Melrose', 'Jazz Gillum', 'Buster Bennett']
#  • Community 56 (2 writers): ['Peggy Clinger', 'Johnny Cymbal']
#  • Community 57 (2 writers): ['Tom Baird', 'Nick Zesses']
#  • Community 58 (2 writers): ['Jerry Monday', 'Mervin Shiner']
#  • Community 59 (2 writers): ['Diane Berglund', 'Jim Phillips']
#  • Community 60 (2 writers): ['Joachim Young', 'Doug Rauch']
#  • Community 61 (2 writers): ['Peter Gosling', 'Alan Hawkshaw']
#  • Community 62 (9 writers): ['Walter Lester', 'Lennie Martin', 'William King III', 'Janet Vogel', 'Joseph Verscharen', 'Jimmy Beaumont', 'John Taylor', 'Joe Rock', 'Larry Martin']
#  • Community 63 (2 writers): ['Eddie Farrell', 'Tommy Dean']
#  • Community 64 (2 writers): ['Sir Henry Rowley Bishop', 'John Howard Payne']
#  • Community 65 (2 writers): ['Charlie Craig', 'Larry Atwood']
#  • Community 66 (4 writers): ['Mariainne Gordon', 'Kenny Rogers', 'Milton Brown', 'Steve Glassmeyer']
#  • Community 67 (2 writers): ['Tibério Gaspar', 'Antônio Adolfo']
#  • Community 68 (4 writers): ['Clifford Scott', 'Billy Butler', 'Bill Doggett', 'Berisford “Shep” Shepherd']
#  • Community 69 (3 writers): ['Brent Titcomb', 'Vicky Taylor', 'Richard Miller']
#  • Community 70 (3 writers): ['Steve Voice', 'Peter Yellowstone', 'Mike Tinsley']
#  • Community 71 (2 writers): ['Bob Stone', 'Bob Stone']
#  • Community 72 (2 writers): ['Márcio Borges', 'Nelson Angelo']
#  • Community 74 (3 writers): ['Ira Jay Lichterman', 'R.P. Schneider', 'Willis J. Williams']
#  • Community 153 (2 writers): ['Francia Luban', 'Eddy Howard']
#  • Community 154 (2 writers): ['Melvin Steals', 'Mervin Steals']
#  • Community 155 (2 writers): ['Melissa Manchester', 'Stanley Schwartz']
#  • Community 156 (2 writers): ['顧嘉煇', '盧國沾']
#  • Community 157 (2 writers): ['Lavon Lile', 'Ann J. Morton']
#  • Community 158 (3 writers): ['Jeanne Fitzsimmons', 'Con Cowan', 'Rick Sandler']
#  • Community 159 (2 writers): ['Alan David', 'Lionel Martin']
#  • Community 160 (2 writers): ['Tom Springfield', 'Jim Dale']
#  • Community 161 (2 writers): ['Bryan Blackburn', 'Pierre Louis Lemaire']
#  • Community 162 (2 writers): ['Roberto Sanchez', 'Oscar Anderle']
#  • Community 163 (2 writers): ['Josh Rubins', 'Peter Larson']
#  • Community 164 (2 writers): ['George Flame', 'Joe Beck']
#  • Community 165 (2 writers): ['Kent Sprague', 'Gary Dalton']
#  • Community 166 (3 writers): ['Eleanor Broadwater', 'Dale Hawkins', 'Stanley Lewis']
#  • Community 167 (3 writers): ['Erik Darling', 'Bob Carey', 'Alan Arkin']
#  • Community 168 (2 writers): ['Richard Ziegler', 'Alan Bernstein']
#  • Community 33 (2 writers): ['Scott Mathews', 'Ron Nagle']
#  • Community 73 (2 writers): ['Bill Reichenbach, Jr.', 'Jerry Hey']
#  • Community 16 (2 writers): ['José Menezes', 'Luis Bittencourt']
#  • Community 17 (2 writers): ['Murray MacLeod', 'Jim Messina']
#  • Community 31 (2 writers): ['Art Farmer', 'Annie Ross']
# Wrote JSON → public/data/writer-network-assigned-1970s.json (425 nodes, 347 links)
#
# === Writer–Writer 1980s ===
# Nodes: 497, Edges: 453, Density: 0.0037
# Communities: 186
#  • Community 0 (4 writers): ['Kevin MacMichael', 'Martin Beedle', 'Tony Moore', 'Colin Farley']
#  • Community 1 (4 writers): ['Tone‐Lōc', 'Matt Dike', 'Mike Simpson', 'John King']
#  • Community 2 (8 writers): ['Bobby LaKind', 'John McFee', 'Keith Knudsen', 'Nicolette Larson', 'Carlene Carter', 'Chet McCracken', 'John Herron', 'Zeke Zirngiebel']
#  • Community 4 (2 writers): ['Carl Belew', 'Shelby Singleton']
#  • Community 5 (4 writers): ['Antonio Somma', 'Giuseppe Verdi', 'Francesco Maria Piave', 'Andrea Maffei']
#  • Community 6 (2 writers): ['Paul Baillargeon', 'Marcel Lefebvre']
#  • Community 7 (2 writers): ['Ray Winkler', 'Johnny Hathcock']
#  • Community 8 (6 writers): ['Orestes Vilató', 'Alphonso Johnson', 'Greg Walker', 'Cory Lerios', 'David Sancious', 'Richard Baker']
#  • Community 9 (2 writers): ['Charles Cochran', 'David Miner']
#  • Community 10 (2 writers): ['Johnny Bragg', 'Robert Riley']
#  • Community 11 (2 writers): ['Vincent Calloway', 'Reggie Calloway']
#  • Community 12 (3 writers): ['Bucky Jones', 'Ron Hellard', 'Michael Garvin']
#  • Community 13 (2 writers): ['Martin Jackson', 'Swing Out Sister']
#  • Community 14 (2 writers): ['Gail Boggs', 'Joshua Shneider']
#  • Community 15 (3 writers): ['Hal Willis', 'Ginger Willis', 'Vernon Dee']
#  • Community 16 (2 writers): ['Buck Clayton', 'Dave Lambert']
#  • Community 17 (6 writers): ['Michael Grant', 'Dennis Seaton', 'Freddie Waite', 'Kelvin Grant', 'Patrick Waite', 'Freddie Waite Sr.']
#  • Community 18 (2 writers): ['Gilda Rincón', 'Valentín Rincón']
#  • Community 19 (2 writers): ['Brian Chatton', 'Barry Block']
#  • Community 20 (2 writers): ['Louis Humphrey', 'Darryl Dash']
#  • Community 21 (3 writers): ['Tom Campbell', 'Spady Brannan', 'Randy McCormick']
#  • Community 22 (5 writers): ['風戸慎介', '和泉常寛', '小林泉美', '阿木燿子', '安西史孝']
#  • Community 23 (2 writers): ['Richard Dehr', 'Frank Miller']
#  • Community 24 (3 writers): ['Bill Haley', 'Rusty Keefer', 'Catherine Cafra']
#  • Community 25 (3 writers): ['Charlene Seeger', 'Jerry Blatt', 'Bette Midler']
#  • Community 26 (5 writers): ['Gerard Kenny', 'Drey Shepperd', 'Jack Feldman', 'Lynsey de Paul', 'Marty Panzer']
#  • Community 27 (3 writers): ['Ava Aldridge', 'Cindy Richardson Walker', 'Lenny LeBlanc']
#  • Community 28 (2 writers): ['John Sembello', 'Cruz Baca Sembello']
#  • Community 29 (9 writers): ['Brad Nail', 'Marc Dalton', 'Franz Reuther', 'Brad Howell', 'Frank Farian', 'Helmut Rulofs', 'John Davis', 'Dietmar Kawohl', 'Peter Bischof‐Fallenstein']
#  • Community 30 (3 writers): ['Bob Brabham', 'Archie Jordan', 'Linda Lee Brown']
#  • Community 31 (2 writers): ['Anne Black Montgomery', 'Peter McIan']
#  • Community 32 (2 writers): ['Paul Evans', 'Al Byron']
#  • Community 33 (2 writers): ['Lisa Montgomery', 'Geneva Paschal']
#  • Community 34 (3 writers): ['Gene Levine', 'Pat Alger', 'Eugene Albert Levine']
#  • Community 35 (3 writers): ['Jacques Plante', 'Paul Mauriat', 'Franck Pourcel']
#  • Community 36 (2 writers): ['Mick Ronson', 'Scott Richardson']
#  • Community 37 (2 writers): ['Keats Tyler', 'Larry Brown']
#  • Community 38 (2 writers): ['Joseph Sauter', 'Mike Lewis']
#  • Community 39 (2 writers): ['Steven Ray', 'Steve Birch']
#  • Community 40 (3 writers): ['Mary Hadler', 'Jack Gilbert', 'V.C. Gilbert']
#  • Community 41 (2 writers): ['David Paul Bryant', 'Jan Buckingham']
#  • Community 42 (3 writers): ['Sami McKinney', 'Alex Brown', "Michael O'Hara"]
#  • Community 43 (4 writers): ['Roger Lewis', 'Walter Donovan', 'Dick Jurgens', 'Country Washburne']
#  • Community 44 (3 writers): ['Brad Delp', 'Fran Sheehan', 'Gerry Green']
#  • Community 45 (2 writers): ['Billy Butler', 'Archie Bell']
#  • Community 46 (4 writers): ['Carlos Rigual', 'Rafael Gastón Perez', 'Mario Rigual', 'Carlos Martinoli']
#  • Community 47 (3 writers): ['Ivan Lins', 'Vítor Martins', 'Ronaldo Monteiro de Souza']
#  • Community 120 (7 writers): ['“Deadly” Headley Bennett', 'Lloyd “Judge” Ferguson', 'Robbie Lyn', 'Jackie Mittoo', 'U Brown', 'Fitzroy “Bunny” Simpson', 'Leroy Sibbles']
#  • Community 121 (2 writers): ['Pierre Létourneau', 'Robert Leroux']
#  • Community 122 (4 writers): ['Jill Colucci', 'Austin Roberts', 'James Patrick Dunne', 'Pamela Phillips‐Oland']
#  • Community 123 (2 writers): ['Ed Pease', 'Mike Scarpiello']
#  • Community 124 (2 writers): ['Sarah Johns', 'Jack Rowland']
#  • Community 125 (2 writers): ['Dale Ockerman', 'Chris Thompson']
#  • Community 126 (2 writers): ['Jimmy Crespo', 'Jack Douglas']
#  • Community 127 (3 writers): ['Johnny Mitchell', 'Robert Carr', 'Hy Weiss']
#  • Community 128 (2 writers): ['Bobby Whiteside', 'Richard Parker']
#  • Community 129 (3 writers): ['Jack Lancaster', 'Barry Reynolds', 'Bernie Frost']
#  • Community 130 (3 writers): ['James Jolis', 'Kevin DiSimone', 'Robin Grean']
#  • Community 131 (3 writers): ['Gerald O’Brien', 'Michael Hanson', 'Sam Reid']
#  • Community 132 (3 writers): ['Jon Rosen', 'Karen Manno', 'Nick Martinelli']
#  • Community 133 (2 writers): ['Vincent Stovall', 'Lorraine Cole']
#  • Community 134 (3 writers): ['Billy MacKenzie', 'Boris Blank', 'Dieter Meier']
#  • Community 135 (5 writers): ['Jonathan Cain', 'Michael Bolton', 'Jeff Day', 'Amy Holland', 'Rev. Patrick Henderson']
#  • Community 136 (4 writers): ['Gaynel Hodge', 'Jesse Belvin', 'Curtis Williams', 'Dootsie Williams']
#  • Community 137 (2 writers): ['Lanny Lambert', 'Bobby Flax']
#  • Community 138 (2 writers): ['Robert F. Colesberry', 'Lesley Gore']
#  • Community 139 (2 writers): ['Robbie Patton', 'Linda Mallah']
#  • Community 140 (2 writers): ['James P. Zerface', 'William A. Zerface']
#  • Community 141 (2 writers): ['Mark Andersen', 'Freida Parton-Overstreet']
#  • Community 142 (3 writers): ['Joey Gallo', 'Wardell Potts', 'Susan Pomerantz']
#  • Community 143 (2 writers): ['Larry Stabbins', 'Simon Booth']
#  • Community 144 (2 writers): ['Robert Lafond', 'ISA']
#  • Community 145 (2 writers): ['Woody Bomar', 'Pat McManus']
#  • Community 146 (2 writers): ['Diego Verdaguer', 'Graciela Carballo']
#  • Community 147 (2 writers): ['Phil Kullmann', 'Bojan Vuletic']
#  • Community 148 (2 writers): ['Kathie Baillie', 'Michael Bonagura']
#  • Community 149 (2 writers): ['Tom Hensley', 'Alan Lindgren']
#  • Community 150 (2 writers): ['Henry Sullivan', 'Harry Ruskin']
#  • Community 151 (2 writers): ['Brian Short', 'Ed Hamilton']
#  • Community 152 (2 writers): ['Will D. Campbell', 'Sheldon Curry']
#  • Community 153 (2 writers): ['Sandy Farina', 'Lisa Ratner']
#  • Community 154 (2 writers): ['Robert Belyeu', 'Charles Wright']
#  • Community 155 (2 writers): ['Donald Lyle', 'Regina Belle']
#  • Community 156 (2 writers): ['Burton Cummings', 'Randy Bachman']
#  • Community 157 (2 writers): ['José Padilla Sánchez', 'Eduardo Montesinos']
#  • Community 158 (2 writers): ['Jerry Huffman', 'Jody Chastain']
#  • Community 159 (2 writers): ['Niki Oosterveen', 'George Michalski']
#  • Community 160 (4 writers): ['Urszula Dudziak', 'Jay Clayton', 'Jeanne Lee', 'Lauren Newton']
#  • Community 161 (2 writers): ['Clydene Jackson', 'Catherine Wilmore']
#  • Community 162 (2 writers): ['Beau Charles', 'Buddy Randell']
#  • Community 163 (2 writers): ['Rick Suchow', 'Alan Palanker']
#  • Community 164 (2 writers): ['Jim Photoglo', 'Brian Francis Neary']
#  • Community 165 (2 writers): ['Paulo Jobim', 'Ronaldo Bastos']
#  • Community 166 (2 writers): ['Harry Manfredini', 'John R. Briggs']
#  • Community 167 (2 writers): ['Gordon Grody', 'Carlotta McKee']
#  • Community 169 (2 writers): ['Johnny Beveridge', 'Peter Oakman']
#  • Community 170 (2 writers): ['Donna Sioux Farar', 'Gary P. Nunn']
#  • Community 171 (5 writers): ['Lionel Belasco', 'Paul Baron', 'Lord Invader', 'Morey Amsterdam', 'Jeri Sullivan']
#  • Community 172 (3 writers): ['Teddy Gentry', 'John Jarrard', 'Jeff Cook']
#  • Community 173 (2 writers): ['James Ingram', 'Mark Vieha']
#  • Community 174 (2 writers): ['Roger Bruno', 'Ellen Schwartz']
#  • Community 175 (2 writers): ['Athena Hosey', 'Hal Gordon']
#  • Community 176 (2 writers): ['Brandon Barnes', 'Richard Butler']
#  • Community 177 (2 writers): ['Jeff Jourard', 'Martha Davis']
#  • Community 178 (2 writers): ['Octavia Oestricher', 'Zane Mark']
#  • Community 179 (2 writers): ['Martin Belmont', 'James Eller']
#  • Community 180 (2 writers): ['Terry Frewer', 'Carroll Baker']
#  • Community 181 (3 writers): ['Graham Lamb', 'Maggie Ryder', 'Phil Nicholl']
#  • Community 182 (2 writers): ['Jeff Barnel', 'Michel Jouveaux']
#  • Community 183 (5 writers): ['José Manzo Perroni', 'Xandro Valerio', 'José Antonio Ochaíta', 'Juan Solano Pedrero', 'Hugo Blanco']
#  • Community 184 (2 writers): ['Mary Unobsky', 'Danny Ironstone']
#  • Community 185 (2 writers): ['Greg Guidry', 'Cindy Guidry']
#  • Community 104 (2 writers): ['Karla DeVito', 'Robby Benson']
#  • Community 97 (2 writers): ['Herman Brightman', 'Larry Lucie']
#  • Community 3 (2 writers): ['Charlie Skarbek', 'Tim Smit']
#  • Community 168 (2 writers): ['Ángel Cabral', 'Enrique Dizeo']
# Wrote JSON → public/data/writer-network-assigned-1980s.json (497 nodes, 453 links)
#
# === Writer–Writer 1990s ===
# Nodes: 2455, Edges: 3512, Density: 0.0012
# Communities: 586
#  • Community 0 (38 writers): ['Kevin Deane', 'Tara Geter', 'Bryce "Luvah" Wilson', 'Babyface', 'Malik Pendleton', 'Kenneth Kelly', 'Daryl Simmons', 'Jon B.', 'Vincent Herbert', 'Mary Brown', '…']
#  • Community 1 (3 writers): ['Herbert Kretzmer', 'Alain Boublil', 'Claude‐Michel Schönberg']
#  • Community 2 (2 writers): ['Leon Patillo', 'David Rubinson']
#  • Community 3 (7 writers): ['Bill Berry', 'Peter Buck', 'Mike Mills', 'Michael Stipe', 'Jerry Ayers', 'Matthew Sweet', 'Neil Bogan']
#  • Community 4 (2 writers): ['Marvin Moore', 'George Campbell']
#  • Community 5 (9 writers): ['Luigi Illica', 'Giuseppe Giacosa', 'Giacomo Puccini', 'Giovacchino Forzano', 'Domenico Oliva', 'Marco Praga', 'Giulio Ricordi', 'Guelfo Civinini', 'Carlo Zangarini']
#  • Community 6 (36 writers): ['Jim Reeves', 'Tom Perryman', 'Joe Allison', 'Audrey Allison', 'Roger Miller', 'Max D. Barnes', 'Hank Cochran', 'Vern Gosdin', 'Billy Guitar', 'Bobby Warren', '…']
#  • Community 7 (87 writers): ['Mike Stoller', 'Jerry Leiber', 'Ben E. King', 'Sally Jo Dakota', 'Nikita Germaine', 'Roy C. Bennett', 'Sid Tepper', 'Barry Mann', 'Warren Casey', 'Jim Jacobs', '…']
#  • Community 8 (7 writers): ['Duke Erikson', 'Steve Marker', 'Shirley Manson', 'Butch Vig', 'Mick Jones', 'Paul Simonon', 'Joe Strummer']
#  • Community 9 (2 writers): ['Tommy Thomas', 'Joe Nixon']
#  • Community 10 (7 writers): ['Luis Gómez Escolar', 'Cesar Lemos', 'Karla Aponte', 'Ian Blake', 'K.C. Porter', 'Luis Ángel', 'Manolo Tena']
#  • Community 11 (3 writers): ['Neville Potter', 'Chick Corea', 'Bobby McFerrin']
#  • Community 12 (66 writers): ['Steve Dorff', 'Amy Grant', 'Tom Hemby', 'Mark Mueller', 'Michael Omartian', 'John Bettis', 'Keith Thomas', 'Brenda Russell', 'Jeff Hull', 'Tom Snow', '…']
#  • Community 13 (48 writers): ['Molly Ann Leikin', 'Rory Bourke', 'Norris “Norro” Wilson', 'Billy Sherrill', 'Even Stevens', 'David Malloy', 'Thom Schuyler', 'Charlie Rich', 'Charlie Black', 'Don Potter', '…']
#  • Community 14 (11 writers): ['Shawn Colvin', 'John Leventhal', 'Kenny White', 'Marc Cohn', 'Tom Littlefield', 'Mark Goldenberg', 'Neil Finn', 'Rick Rowell', 'Kevin Salem', 'Doug Petty', '…']
#  • Community 15 (20 writers): ['Berry Gordy', 'Bob West', 'Willie Hutch', 'Hal Davis', 'Janie Bradford', 'Junie Morrison', 'Marshall Jones', 'Greg Webster', 'Joe “The Butcher” Nicolo', 'Leroy Bonner', '…']
#  • Community 16 (11 writers): ['Rick Chertoff', 'Joan Osborne', 'Rob Hyman', 'Eric Bazilian', 'Chris Palmaro', 'Sammy Merendino', 'Stewart Lerman', 'Don van Vliet', 'Erik Della Penna', 'Jack Petruzzelli', '…']
#  • Community 17 (63 writers): ['Steven Tyler', 'Joe Perry', 'Albert Hammond', 'Graham Lyle', 'Mike Chapman', 'Holly Knight', 'Glen Ballard', 'Siedah Garrett', 'Sam Hogin', 'Philip Donnelly', '…']
#  • Community 18 (10 writers): ['Fulani Faluke', 'Speech', 'Arrested Development', 'Al Jackson, Jr.', 'Willie Mitchell', 'Al Green', 'Headliner', 'Junior Wells', 'Buddy Guy', 'Baba Oje']
#  • Community 19 (29 writers): ['Larry Mullen, Jr.', 'Adam Clayton', 'Bono', 'The Edge', 'Edwin Othello Excell', 'John Newton', 'Bob Dylan', 'Marvin Gaye', 'Maurice Seezer', 'Gavin Friday', '…']
#  • Community 31 (23 writers): ['Tim Rice', 'Andrew Lloyd Webber', 'Richard Stilgoe', 'Charles Hart', 'B.A. Robertson', 'Mike Rutherford', 'Jon Carin', 'Bob Ezrin', 'Polly Samson', 'Nick Laird-Clowes', '…']
#  • Community 21 (7 writers): ['Seth Swirsky', 'Arnie Roman', 'Arthur Jacobson', 'Peter Zizzo', 'Jimmy Bralower', 'Tina Shafer', 'Sheena Easton']
#  • Community 22 (2 writers): ['Oley Speaks', 'Rudyard Kipling']
#  • Community 23 (2 writers): ['Roy Orbison', 'Joe Melson']
#  • Community 24 (3 writers): ['Mick Jagger', 'Keith Richards', 'Dick Halligan']
#  • Community 25 (11 writers): ['Tré Cool', 'Billie Joe Armstrong', 'Mike Dirnt', 'John Kiffmeyer', 'Randy Rhoads', 'Bob Daisley', 'Tony Cavazo', 'Kevin DuBrow', 'Cliff Burton', 'Carlos Cavazo', '…']
#  • Community 26 (2 writers): ['Antonio Amurri', 'Bruno Canfora']
#  • Community 28 (8 writers): ['Robert Hart', 'Dave Colwell', 'Brian Howe', 'Terry Thomas', 'Michael Lister', 'Terry Finley', 'Rick Wills', "Kevin Michael O'Neill"]
#  • Community 29 (25 writers): ['Neneh Cherry', 'Cameron McVey', 'Jonathan Sharp', 'Johnny Turnbull', 'Mark Saunders', 'Tricky', 'Anthony Jackson', 'Kenneth Gamble', 'Adrian Thaws', 'Cia Berg', '…']
#  • Community 30 (7 writers): ['John Payne', 'Aziz Ibrahim', 'Andy Nye', 'Gregory Hart', 'Elliott Randall', '布袋寅泰', 'Mike Sturgis']
#  • Community 64 (123 writers): ['Michael McCary', 'Stevie J', 'Wanya Morris', 'Gregory Johnson', 'Shawn Stockman', 'Diddy', 'Ron Lawrence', 'Nathan Morris', 'Peter Vale', 'Mick Leeson', '…']
#  • Community 33 (5 writers): ['Kenneth Allan Barken', 'Roxanne Seeman', 'Cristóvão Bastos', 'Abel Silva', 'Billie Hughes']
#  • Community 35 (10 writers): ['Siobhan Fahey', 'Keren Woodward', 'Sara Dallin', 'Steve Jolley', 'Tony Swain', 'Kari Kimmel', 'Leo Birenberg', 'Jonas Berggren', 'Ulf Ekberg', 'Douglas Carr']
#  • Community 36 (4 writers): ['Keb’ Mo’', 'Elmore James', 'Mel London', 'Billy Myles']
#  • Community 37 (15 writers): ['Don Henley', 'Bruce Hornsby', 'Glenn Frey', 'Paul Gurian', 'John Corey', 'John Hornsby', 'Jim Ed Norman', 'Danny Kortchmar', 'Benmont Tench', 'Don Felder', '…']
#  • Community 38 (3 writers): ['Sonny Sanders', 'Carolyn Franklin', 'Sony Saunders']
#  • Community 39 (4 writers): ['William Henri Woode', 'Teddy McRae', 'Bill Bird', 'Wynonie Harris']
#  • Community 40 (7 writers): ['Petula Clark', 'Vito Pallavicini', 'Simon Napier-Bell', 'Vicki Wickham', 'Pino Donaggio', 'Dee Shipman', 'Kenny Clayton']
#  • Community 41 (5 writers): ['Paul Christie', 'Danny Peyronel', 'Meat Loaf', 'John Golden', 'Mark Doyle']
#  • Community 42 (5 writers): ['John Denver', 'Taffy Nivert', 'Bill Danoff', 'Jean Bouchéty', 'Jean-Pierre Bourtayre']
#  • Community 43 (5 writers): ['Nick LaRocca', 'Tony Sbarbaro', 'Eddie Edwards', 'Larry Shields', 'Henry Ragas']
#  • Community 45 (4 writers): ['Tommie Connor', 'Michael Carr', 'Jimmy Kennedy', 'Georges Boulanger']
#  • Community 47 (2 writers): ["Paul O'Donoughue", 'Dave Pickerill']
#  • Community 48 (9 writers): ['Joe Sherman', 'Noel Sherman', 'Neil Sedaka', 'Howard Greenfield', 'Jack Keller', 'Freddy Douglass', 'Sol Kaplan', 'Hank Hunter', 'Helen Miller']
#  • Community 49 (2 writers): ['Bobby Scott', 'Ric Marlow']
#  • Community 50 (3 writers): ['Lloyd Tolbert', 'Cydney Davis', 'James Anthony Carmichael']
#  • Community 52 (2 writers): ['Milton Sparks', 'Aaron Sparks']
#  • Community 53 (5 writers): ['Jennifer Rush', 'Gunther Mende', 'Mary Applegate', 'Wolfgang Detmann', 'P.G. Wilder']
#  • Community 54 (2 writers): ['Ken Barry', 'Joe Bentley']
#  • Community 55 (3 writers): ['Katherine K. Davis', 'Harry Simeone', 'Henry Onorati']
#  • Community 56 (8 writers): ['Will Mowat', 'Beresford Romeo', 'Simon Law', 'Caron Wheeler', 'Hayden MacLaren Browne', 'Ross Anderson', 'Kym Mazelle', 'Jason Chue']
#  • Community 57 (3 writers): ['Lulu', 'Billy Lawrie', 'Steve DuBerry']
#  • Community 58 (3 writers): ['Marvin Yancy', 'Chuck Jackson', 'Chuck Jackson']
#  • Community 68 (23 writers): ['Toni Estes', 'Isaac Phillips', 'George Frideric Handel', 'Isaac Watts', 'Thomas Morell', '[unknown]', 'Victor Herbert', 'Joseph Kosma', 'Jacques Prévert', 'C. Maude Battersby', '…']
#  • Community 60 (8 writers): ['Carl Perkins', 'Rex Griffin', 'Stan Perkins', 'Greg Perkins', 'Quinton Claunch', 'Bill Cantrell', 'Rob Crosby', 'Dottie Moore']
#  • Community 61 (8 writers): ['Harry Wayne Casey', 'Richard Finch', 'Deborah Carter', 'KC', 'Ken Gibson', 'Nate Edmonds', 'Brenda Reynolds', 'Albert Williams']
#  • Community 62 (3 writers): ['Ry Cooder', 'Jim Dickinson', 'John Hiatt']
#  • Community 63 (3 writers): ['Mac Gayden', 'James “Buzz” Cason', 'Tony Moon']
#  • Community 65 (2 writers): ['Matt Black', 'Jonathan More']
#  • Community 66 (2 writers): ['Operation Ivy', 'Jesse Michaels']
#  • Community 67 (6 writers): ['Chris Solberg', 'Alex Ligertwood', 'Graham Lear', 'David Margen', 'Pete Escovedo', 'Armando Peraza']
#  • Community 94 (3 writers): ['Cecil Womack', 'Linda Womack', 'Eddie “Gip” Noble']
#  • Community 95 (4 writers): ['Darius Rucker', 'Jim Sonefeld', 'Mark Bryan', 'Dean Felber']
#  • Community 96 (13 writers): ['Sting', 'Mark Knopfler', 'Stewart Copeland', 'Eric Clapton', 'Robert Cray', 'Michael Kamen', 'Martin Sharp', 'Marcy Levy', 'Johnny Otis', 'David Knopfler', '…']
#  • Community 97 (2 writers): ['Roberto Mendoza', 'José Enrique Sarabia']
#  • Community 99 (2 writers): ['James Hendricks', 'William L. Thompson']
#  • Community 100 (2 writers): ['P.F. Sloan', 'Steve Barri']
#  • Community 101 (4 writers): ['Nat Simon', 'Buddy Bernier', 'Robert Emmerich', 'Jerry Brainin']
#  • Community 102 (4 writers): ['David Munday', 'Phil Thornalley', 'Colin Campsie', 'Boo Hewerdine']
#  • Community 103 (4 writers): ['Salvadore Cammarano', 'Gaetano Donizetti', 'Jules-Henri Vernoy de Saint-Georges', 'Jean-François Bayard']
#  • Community 104 (2 writers): ['Al Jacobs', 'Jimmie Crane']
#  • Community 106 (6 writers): ['Shannon Hoon', 'Christopher Thorn', 'Rogers Stevens', 'Glen Graham', 'Brad Smith', 'Howard Boschan']
#  • Community 108 (2 writers): ['Graham Stack', 'John Reid']
#  • Community 109 (2 writers): ['Hector Berlioz', 'Théophile Gautier']
#  • Community 110 (2 writers): ['Carroll Loveday', 'Helmy Kresa']
#  • Community 111 (4 writers): ['Maurice Ravel', 'Franc-Nohain', 'Colette', 'Lucien Garban']
#  • Community 112 (2 writers): ['Ben Black', 'Edwin Lemare']
#  • Community 113 (2 writers): ['Pete Ham', 'Tom Evans']
#  • Community 114 (13 writers): ['David Was', 'Attrell S. Cordes', 'Chris Carter', 'Phil Roy', 'Bob Thiele Jr.', 'Gary Kemp', 'Davey Faragher', 'Clark Anderson', 'John Keller', 'Cameron Greider', '…']
#  • Community 116 (23 writers): ['Luc Plamondon', 'Germain Gauthier', 'Christian Loigerot', 'Thierry Geoffroy', 'Eddy Marnay', 'Peter Sinfield', 'Andy Hill', 'Michel Berger', 'Dario Baldan Bembo', 'Paolo Amerigo Cassella', '…']
#  • Community 117 (2 writers): ['John Themis', 'Michael Craig']
#  • Community 118 (8 writers): ['Leon Roppolo', 'George Brunies', 'Ben Pollack', 'Paul Mares', 'Mel Stitzel', 'Jelly Roll Morton', 'Buddy Bolden', 'Ed Werac']
#  • Community 119 (2 writers): ['Trummy Young', 'Jimmy Mundy']
# ...
#  • Community 25 (40 writers): ['Jamie Spinks', 'RAYE', 'Mark Ralph', 'Mike Sabath', 'shanks.', 'Tom Richards', 'Marvin "Tony" Hemmings', 'Kennedi Lykken', 'Antoinette Smith', 'Eyelar Mirzazadeh', '…']
#  • Community 26 (17 writers): ['Olivia Rodrigo', 'Daniel Nigro', 'Chappell Roan', 'Morgan St. Jean', 'Skyler Stonestreet', 'Annie Schindel', 'Amy Kuney', 'Lixa', 'Jonah Shy', 'Maya Kurchner', '…']
#  • Community 47 (7 writers): ['Car!ton', 'marvy ayy', 'Tom Kahre', 'Cole Bennett', 'John Nocito', 'BabyTron', 'Daniyel']
#  • Community 48 (6 writers): ['Will Hunt', 'Tim McCord', 'Jen Majura', 'Troy McLawhorn', 'Deena Jakoub', 'Nick Raskulinecz']
#  • Community 49 (2 writers): ['Dean Josiah Cover', 'Cleopatra Nikolic']
#  • Community 50 (7 writers): ['Eric Aukstikalnis', 'Jazelle Rodriguez', 'Samuel James Zammarelli', 'Mr. Probz', 'Linus Eklöw', 'Jan Postma', 'Jordi De Fluiter']
#  • Community 52 (2 writers): ['Larry Gottlieb', 'Marc Blatte']
#  • Community 53 (23 writers): ['Jason Suwito', 'Benson Boone', 'Jack LaFrantz', 'Blair', 'Nolan Sipe', 'JT Daly', 'Alida', 'Nathan Cunningham', 'Marc Sibley', 'Alma Goodman', '…']
#  • Community 54 (6 writers): ['Stephen Dewaele', 'Michael Champion', 'David Dewaele', 'Rhian Teasdale', 'Hester Chambers', 'Joshua Mobaraki']
#  • Community 56 (9 writers): ['George Tizzard', 'Rick Parkhouse', 'Luke Fitton', 'Rachel Furner', 'Chiara Hunter', 'Samuel Preston', 'Dimitri Vangelis', 'Mikael Persson', 'Wyman']
#  • Community 57 (2 writers): ['JC Chasez', 'Vincent Degiorgio']
#  • Community 58 (2 writers): ['Michael Weiner', 'Alan Zachary']
#  • Community 59 (5 writers): ['Marc Veira', 'Trigga', 'IRah', 'Bou', 'Jem Cooke']
#  • Community 60 (5 writers): ['Jake Kiszka', 'Sam Kiszka', 'Joshua Kiszka', 'Daniel Wagner', 'Dave Cobb']
#  • Community 61 (4 writers): ['神田ジョン', '安藤紗々', '大和', '島みやえい子']
#  • Community 62 (2 writers): ['Evan McKeever', 'Ryan Carpenter']
#  • Community 64 (14 writers): ['Ice Spice', 'RIOTUSA', 'Venny', 'Synthetic', 'Daniel Eisner Harle', 'PinkPantheress', 'Corbin', 'Lene', 'Delgado', 'Johnny Pederson', '…']
#  • Community 65 (2 writers): ['Sheldon Feinberg', 'Ronald Dean Badger']
#  • Community 68 (6 writers): ['Molly Tuttle', 'Ketch Secor', 'Melody Walker', 'Mark Simos', 'Steve Poltz', 'Becky Buller']
#  • Community 70 (15 writers): ['Smarterchild', 'Remy Gautreau', 'Gayathri Karunakar Menon', 'Ava Brignol', 'Bea Miller', 'ellis', 'Gilletary', 'Remi Wolf', 'dwilly', 'Micah Premnath', '…']
#  • Community 71 (4 writers): ['Monty Holmes', 'Michael Huffman', 'Shawn Camp', 'Charles R. Humphrey III']
#  • Community 72 (2 writers): ['Christoph Göttsch', 'Daniel Brems']
#  • Community 74 (6 writers): ['Tarik Azzouz', 'E. Blackmon', 'F. LeBlanc', 'Amos Roddy', 'Donald Breedlove', 'Napoleon Crayton']
#  • Community 75 (7 writers): ['Bobby “Keyz” Reese', 'Kevin Yancey', 'Javar Rockamore', 'Theodore “Stonii” Thomas', 'Keith “City” Martin', 'Daniel Groover', 'Fuse']
#  • Community 76 (2 writers): ['Michael Kiwanuka', 'Paul Butler']
#  • Community 78 (5 writers): ['Jen Jis', 'Conor Blake', 'Noraa', 'Melody Gardot', 'Hilda Stenmalm']
#  • Community 79 (2 writers): ['James Glen', 'Quentin Reynolds']
#  • Community 80 (8 writers): ['Vaiyeh', 'Marcus Semaj', 'Bryson Tiller', 'Xavier Smith', 'Chef Tone', 'Tyler Williams', 'Kenny Kornegay', 'Darryl "88" Young']
#  • Community 81 (6 writers): ['Hanni Ibrahim', 'Mr. Bristal', 'Amanda Atoui', 'Abby-Lynn Keen', 'Patrick Jordan-Patrikios', 'Avital Margulies']
#  • Community 82 (9 writers): ['David Garcia', 'David Garcia', 'Lydia Vaughan', 'John Morgan', 'Tully Kennedy', 'Kurt Allison', 'Summer Overstreet', 'Emily Landis', 'Lauren Watkins']
#  • Community 83 (3 writers): ['Tommy Genesis', 'Mike Hermosa', 'Benji Lysaght']
#  • Community 84 (3 writers): ['Andrea Yvette Summers', 'Kelman Duran', 'Tommy Wright III']
#  • Community 85 (18 writers): ['D.A. Got That Dope', 'Ezemdi Chikwendu', 'Dominik Redenczki', 'Alejandro Villasana', 'White Gold', 'Narza', 'Luca Mauti', 'Danny Levin', 'Christina Doman', 'mars.', '…']
#  • Community 86 (3 writers): ['Ahadadream', 'Japhna Gold', 'Priya Ragu']
#  • Community 87 (2 writers): ['Dion', 'Mike Aquilina']
#  • Community 88 (2 writers): ['Terry Britten', 'Kygo']
#  • Community 89 (3 writers): ['Kenyon Dixon', 'Elliott Ives', 'Tobe Nwigwe']
#  • Community 90 (2 writers): ['Bradley Nowell', 'Marshall Goodman']
#  • Community 91 (3 writers): ['Jason Kellner', 'Denis Kosiak', 'Chase Hugh Worrell']
#  • Community 92 (2 writers): ['Shane MacGowan', 'Jem Finer']
#  • Community 93 (5 writers): ['Michael L. Grier', 'MC Shan', 'Snow', 'Edmond Leary', 'Terri Moltke']
#  • Community 94 (2 writers): ['Hayden Silas Anhedönia', 'Steven Mark Colyer']
#  • Community 95 (2 writers): ['Elisse Boyd', 'Murray Grand']
#  • Community 96 (2 writers): ['Bear McCreary', 'J.R.R. Tolkien']
#  • Community 97 (5 writers): ['Lance Quinn', 'DJ Mighty Mi', 'Brad Baker', 'Joe Thomas', 'Mr. Eon']
#  • Community 98 (3 writers): ['Chuck Grant', 'Rob Grant', 'Alana Champion']
#  • Community 99 (4 writers): ['Alex Sino', 'Леонид Агутин', 'Richard Bravo', 'Camilo Valencia']
#  • Community 100 (2 writers): ['Nelson Shawn', 'Caesar Petrillo']
#  • Community 101 (2 writers): ['John Fitch', 'Daryl Harleaux']
#  • Community 102 (2 writers): ['Tom Mann', 'Daniel Priddy']
#  • Community 103 (2 writers): ['作良弘平', '都築真紀']
#  • Community 104 (6 writers): ['Brandon Flowers', 'Dave Keuning', 'Ronnie Vannucci Jr.', 'Mark Stoermer', 'Shawn Everett', 'Jonathan Rado']
#  • Community 105 (3 writers): ['Mimi Parker', 'Alan Sparhawk', 'John Nichols']
#  • Community 106 (2 writers): ['Gregory Alan Isakov', 'Ron Scott']
#  • Community 107 (2 writers): ['Forrest Frank', 'Colin Padalecki']
#  • Community 108 (5 writers): ['Richard Fagan', 'John Michael Montgomery', 'Mike Anthony', 'Steve O’Brien', 'Larry Alderman']
#  • Community 109 (2 writers): ['Jim Fox', 'Dale Peters']
#  • Community 110 (2 writers): ['Lech Wierzynski', 'Yanos Lustig']
#  • Community 111 (2 writers): ['Skoob', 'Krazy Drayz']
#  • Community 112 (2 writers): ['Vicki Arnold', 'Les McCann']
#  • Community 113 (2 writers): ['KEEN', '森雪之丞']
#  • Community 114 (4 writers): ['Armando Pérez', 'Teddy Sky', 'Ulises Hermosa', 'Gonzalo Hermosa']
#  • Community 115 (2 writers): ['Austin Lichtenstein', 'Pete Miller']
#  • Community 116 (4 writers): ['Patrick Clancy', 'Tom Clancy', 'Liam Clancy', 'Bobby Clancy']
#  • Community 117 (2 writers): ['Mason Ramsey', 'Dan Fernandez']
#  • Community 118 (2 writers): ['Tanya Trotter', 'Michael Trotter']
#  • Community 119 (3 writers): ['KT Tunstall', 'Tim Bran', 'Roy Kerr']
#  • Community 120 (2 writers): ['Jerry Weaver', 'Posie Knight']
#  • Community 121 (2 writers): ['Betty Nelson', 'Ahmet Ertegun']
#  • Community 122 (2 writers): ['Maxx Morando', 'Harmony Korine']
#  • Community 123 (2 writers): ['Mark Lowry', 'Buddy Greene']
#  • Community 124 (8 writers): ['Harjot Kaur Singh', 'TAICHU', 'Joseph Freimuth', 'Michael Woods', 'Hamdi', 'Johnny Doswell', 'Cat Connors', 'Kenneth Wilkins']
#  • Community 125 (2 writers): ['Joell Ortiz', 'KXNG Crooked']
#  • Community 126 (3 writers): ['Scott Hutchison', 'Simon Liddell', 'Andy Monaghan']
#  • Community 129 (2 writers): ['Jack Daniels', 'Bonnie Thompson']
#  • Community 130 (3 writers): ['Dave Hamilton', 'Rony Darrell', 'Ann Bridgeforth']
#  • Community 131 (2 writers): ['DJ Zki', 'Dobre']
#  • Community 132 (2 writers): ['Anthony Gonzalez', 'Morgan Kibby']
#  • Community 133 (2 writers): ['Yann Tiersen', 'Eli Keszler']
#  • Community 134 (2 writers): ['Laura Rogers', 'Lydia Rogers']
#  • Community 135 (6 writers): ['Ovimael Burgos "OMB"', 'Angel Jovian Barbosa Diaz', 'Dímelo Flow', 'Johnny Oscar López Pimentel', 'Héctor Emmanuel Birriel Caraballo', 'Slow Mike']
#  • Community 136 (4 writers): ['Sexyy Red', 'Jake Fridkis', 'King Willonius', 'Luh Ron']
#  • Community 137 (6 writers): ['Miles Kane', 'Jamie Biles', 'Zachary Dawes', 'Drew Erickson', 'Loren Humphrey', 'Tyler Parkford']
#  • Community 138 (2 writers): ['Bobby Tomberlin', 'Ryan Larkins']
#  • Community 139 (2 writers): ['Phill Brown', 'Steve Smith']
#  • Community 140 (2 writers): ['Jimi Bell', 'Joe Fox']
#  • Community 141 (3 writers): ['James Smith', 'Ryan Needham', 'Sam Shipstone']
#  • Community 142 (2 writers): ['Samora Pinderhughes', 'Jack DeBoe']
#  • Community 143 (2 writers): ['Pearl White', 'Al White']
#  • Community 144 (3 writers): ['Carrie Brownstein', 'Corin Tucker', 'Janet Weiss']
#  • Community 145 (2 writers): ['Jann Browne', 'Matt Barnes']
#  • Community 147 (6 writers): ['Justyn Pilbrow', 'Jeremy Freedman', 'Brandon Fried', 'Mikey Margott', 'Jesse', 'Zachary Abels']
#  • Community 148 (2 writers): ['Adam Watts', 'Andy Dodd']
#  • Community 149 (2 writers): ['Hannah V', 'Yola']
#  • Community 150 (2 writers): ['Christopher Thomas', 'Brian Blade']
#  • Community 151 (3 writers): ['Samuel Read', 'Ben Foster', 'Charles Monneraud']
#  • Community 152 (3 writers): ['Aaron Allen', 'Billy Strings', 'Jon Weisberger']
#  • Community 153 (2 writers): ['William M. Runyan', 'Thomas Obadiah Chisholm']
#  • Community 154 (2 writers): ['Zach Sobiech', 'Samantha Brown']
#  • Community 155 (3 writers): ['KEN', 'JUNE', 'Philip Woo']
#  • Community 156 (2 writers): ['John Bryan', 'Gareth Moulton']
#  • Community 157 (3 writers): ['Sean O’Keeffe', 'Simon Colebrooke', 'Rob Playford']
#  • Community 158 (2 writers): ['Rosi Golan', 'Billy Crabtree']
#  • Community 159 (3 writers): ['Varren Wade', 'Quintin Gulledge', 'Quinton Gulledge']
#  • Community 160 (3 writers): ['Mick Grondahl', 'Matt Johnson', 'Jeff Buckley']
#  • Community 161 (2 writers): ['Richard Shepherd', 'Jean Shepherd']
#  • Community 162 (3 writers): ['Michael Shimmin', 'Tyler Duncan', 'John McSherry']
#  • Community 163 (2 writers): ['Sir William Watson', 'Frances Allitsen']
#  • Community 164 (4 writers): ['Wille Tannergaard', 'George Morgan', 'Cat Burns', 'JonahPH']
#  • Community 165 (3 writers): ['Sarcastic Sounds', 'David Jackson', 'Eryn Allen Kane']
#  • Community 166 (3 writers): ['Justus Nnakwe', 'Drago Uboma', 'Stoneface Iwuagwu']
#  • Community 167 (3 writers): ['Michael Jade', 'Hillary Reynolds', 'Trevor Jarvis']
#  • Community 168 (3 writers): ['Daniel Carter Aranson', 'Prentiss', 'Anthony Green']
#  • Community 169 (3 writers): ['Dominic Hawken', 'Tony Mortimer', 'Rob Kean']
#  • Community 170 (3 writers): ['Francesco Catitti', 'Cheope', 'Federica Abbate']
#  • Community 171 (2 writers): ['Gloria Gaither', 'Bill Gaither']
#  • Community 172 (2 writers): ['Billy Stritch', 'Sandy Knox']
#  • Community 173 (2 writers): ['Inga Willis', 'Dante Ross']
#  • Community 174 (2 writers): ['Gustav Mahler', 'Friedrich Gottlieb Klopstock']
#  • Community 175 (3 writers): ['Anthony Williams', 'Keith Bailey', 'Rob Swift']
#  • Community 176 (2 writers): ['William Gorman Wills', 'Frederic Clay']
#  • Community 177 (2 writers): ['Tyler Andrew Duncan', 'Theo Katzman']
#  • Community 178 (2 writers): ['Samara Joy', 'Fats Navarro']
#  • Community 179 (2 writers): ['Jonna Lee', 'Claes Björklund']
#  • Community 180 (3 writers): ['Robert Sharenow', 'Daniel Miller', 'William Shatner']
#  • Community 181 (2 writers): ['Anna Waronker', 'Craig Wedren']
#  • Community 182 (2 writers): ['Tyrese Ryan', 'Ethan Holt']
#  • Community 183 (2 writers): ['Frank Mertens', 'Bernhard Lloyd']
#  • Community 184 (2 writers): ['Jelly Roll', 'David Ray']
#  • Community 185 (2 writers): ['Derek Cruz', 'Don DiLego']
#  • Community 186 (2 writers): ['Doree Post', 'Bill Post']
#  • Community 187 (2 writers): ['Emily Armstrong', 'Alex Seaver']
#  • Community 188 (2 writers): ['Rennie Sparks', 'Brett Sparks']
#  • Community 189 (2 writers): ['Cosimo Matassa', 'Jimmy Clanton']
#  • Community 190 (6 writers): ['Andrew Fitzpatrick', 'Christopher Messina', 'Jenn Wasner', 'Sam Tsang', 'Dijon Duenas', 'Dijon']
#  • Community 191 (3 writers): ['Arooj Aftab', 'Shahzad Ismaily', 'Vijay Iyer']
#  • Community 192 (2 writers): ['Richard Melville Hall', 'Mark Lanegan']
#  • Community 193 (2 writers): ['Lars Frederiksen', 'Matt Freeman']
#  • Community 194 (2 writers): ['Julian Bailey', 'Freddie Allen']
#  • Community 195 (2 writers): ['Eddie Ray', 'Rudy Jackson']
#  • Community 196 (2 writers): ['Barry Jobe', 'Jada Star Anderson‐Roberts']
#  • Community 128 (4 writers): ['Himanshi Bokadiya', 'Shreyans Bokadiya', 'Malay Kantharia', 'Sage Yashovjay Ji']
#  • Community 6 (2 writers): ['Tiziano Ferro', 'Matt Sheeran']
#  • Community 7 (2 writers): ['Jeffrey Fayman', 'Daniel Pursey']
#  • Community 8 (2 writers): ['Michael Trent', 'Bill Carson']
#  • Community 9 (2 writers): ['Natra Average', 'prxz']
#  • Community 13 (3 writers): ['Greg Wojahn', 'Scott Wohahn', 'Roger Wohahn']
#  • Community 146 (2 writers): ['Al Scramuzza', 'Edwin Bocage']
#  • Community 19 (3 writers): ['Monty Criswell', 'Billy Spencer', 'Greg McDougal']
#  • Community 24 (2 writers): ['Andy Chase', 'Dominique Durand']
#  • Community 29 (5 writers): ['Gord Downie', 'Gord Sinclair', 'Rob Baker', 'Johnny Fay', 'Paul Langlois']
#  • Community 33 (2 writers): ['Kayzo', 'Keaton Prescott']
#  • Community 36 (2 writers): ['Indrr Bajwa', 'Diljit Dosanjh']
#  • Community 37 (3 writers): ['John Webb, Jr.', 'Jamil DeBardlabon', 'Are Sorknes']
#  • Community 44 (2 writers): ['Mike McQuerry', 'Richard Albert Alves']
#  • Community 45 (3 writers): ['William Shelby', 'Leon Sylvers', 'Stephen Shockley']
#  • Community 66 (2 writers): ['Peter Harper', 'Jason Blynn']
#  • Community 69 (2 writers): ['Chill Shump', 'Rivs on da Beat']
#  • Community 73 (2 writers): ['Степан Миколайович Чарнецький', 'Андрій Хливнюк']
#  • Community 77 (2 writers): ['Evan Dando', 'Tom Morgan']
# Wrote JSON → public/data/writer-network-assigned-2020s.json (2479 nodes, 8259 links)
